-- %% [markdown]
-- # <span style="font-size: 20pt; font-family: Montserrat, sans-serif; color: rgb(92, 148, 206); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Graded Assignment 3: 9 to 5</span>
--
--
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to show off your SQL skills! For each question, copy the SQL query you used and make note of the answer.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For this assignment, you will be using the Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results which can be found on</span> [<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(17, 85, 204); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; text-decoration-line: underline; vertical-align: baseline; white-space: pre-wrap;">Kaggle</span>](https://www.kaggle.com/bls/employment)<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Business Issue</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">You are working for the Bureau of Labor Statistics with the United States government and have been approached by your boss with an important meeting request. You have been asked by your supervisor to meet with Dolly Parton whose nonprofit is looking to shed light on the state of employment in the United States. As part of the 9 to 5 project, their research is focused on production and nonsupervisory employees and how those employees fare compared to all employees in the United States. While the data the BLS collects from the CES is publicly available, Dolly Parton and her colleagues need your assistance navigating the thousands of rows in each table in LaborStatisticsDB.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">About the Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">This dataset comes directly from the Bureau of Labor Statistics’ Current Employment Survey (CES). Here are some things you need to know:</span>
--
-- 1. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The industry table contains an NAICS code. This is different from the industry code. NAICS stands for North American Industry Classification System.</span>
--
-- 2. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Series ID is composed of multiple different codes. CES stands for Current Employment Survey, the name of the survey which collected the data. The industry code as specified by the BLS and the data type code as specified in the datatype table.</span>
--
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Set Up</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To connect to the database, use the same connection info used during the SQL lessons.&nbsp;</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For the assignment, we will be using the LaborStatisticsDB database.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Database Exploration</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To start with, let’s get to know the database further.</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 10pt; white-space: pre-wrap;">Use this space to make note of each table in the database, the columns within each table, each column’s data type, and how the tables are connected. You can write this down or draw a diagram. Whatever method helps you get an understanding of what is going on with LaborStatisticsDB.</span>

-- %% [markdown]
-- To add a photo, diagram or document to your file, drop the file into the folder that holds this notebook.  Use the the link button to the right of the  \</\> symbol in the gray part of this cell, the link is just the name of your file.

-- %% [markdown]
-- ![](data:image/png;base64,...)

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">What is the datatype for women employees?</span>

-- %%
select distinct data_type_code 
from datatype
where data_type_text = 'women employees';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.052
-- <table><tr><th>data_type_code</th></tr><tr><td>10</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the series id for&nbsp; women employees in the commercial banking industry in the financial activities supersector?</span>

-- %%
select distinct s.series_id
from series s 
inner join supersector su on su.supersector_code = s.supersector_code
inner join industry i on i.industry_code = s.industry_code
where su.supersector_name = 'financial activities' and i.industry_name = 'commercial banking' and s.data_type_code = 10;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.164
-- <table><tr><th>series_id</th></tr><tr><td>CES5552211010</td></tr><tr><td>CEU5552211010</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Join in on the Fun</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to start joining! You can choose the type of join you use, just make sure to make a&nbsp; note!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join&nbsp; annual_2016 with series on series_id. We only want the data in the annual_2016 table to be included in the result.</span>

-- %%
SELECT a.series_id
from LaborStatisticsDB.dbo.annual_2016 as a 
left outer join LaborStatisticsDB.dbo.series as s 
on a.series_id = s.series_id;
-- Out:
-- (29042 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00
-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Aggregate Your Friends and Code some SQL</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Put together the following:</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; No chopping people into little bits, please. Totally 2,340,612 employees were reported in 2016 in all industries.</span>

-- %%
SELECT round (sum(a.value), 0) 
from annual_2016 a
inner join series s on s.series_id = a.series_id
where s.data_type_code = 1;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.173
-- <table><tr><th>(No column name)</th></tr><tr><td>2340612</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many women employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp;There were 1,125,490 women empolyee reported in 2016</span>

-- %%
select sum (a.value)
from annual_2016 a 
inner join series s on s.series_id = a.series_id
where s.data_type_code = 10;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.103
-- <table><tr><th>(No column name)</th></tr><tr><td>1125489.6000000008</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many production/nonsupervisory employees were reported in 2016? Round to the nearest whole number.&nbsp;Totally there were 1,263,650 employees in 2016.</span>

-- %%
select round (sum(a.value), 0)
from annual_2016 a
inner join series s on s.series_id = a.series_id
where s.data_type_code = 6;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.129
-- <table><tr><th>(No column name)</th></tr><tr><td>1263650</td></tr></table>

-- %% [markdown]
-- 4. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, what is the average weekly hours worked by production and nonsupervisory employees across all industries? The average weekly hours is 36.1</span>

-- %%
select avg(value)
from january_2017 j
inner join series s on s.series_id = j.series_id
where s.data_type_code = 7;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.151
-- <table><tr><th>(No column name)</th></tr><tr><td>36.05862068965521</td></tr></table>

-- %% [markdown]
-- 5. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the total weekly payroll for production and nonsupervisory employees across all industries in January 2017? Round to the nearest penny, please. The Total weekly payroll is: 1838753220</span>

-- %%
select sum(round(j.value, 2))
from january_2017 j 
inner join series s on s.series_id = j.series_id
inner join datatype d on s.data_type_code = d.data_type_code
where s.data_type_code = 82;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.172
-- <table><tr><th>(No column name)</th></tr><tr><td>1838753220</td></tr></table>

-- %% [markdown]
-- 6. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, which industry was the average weekly hours worked by production and nonsupervisory employees the highest? Which industry was the lowest? The Highest was </span> <span style="font-size: 13.3333px; white-space: pre-wrap;">Motor vehicle power train components. The Lowest was Fitness and recreational sports centers.</span>

-- %%
select i.industry_name 
from january_2017 j 
inner join series s on j.series_id = s.series_id
inner join industry i on i.industry_code = s.industry_code
where s.data_type_code = 7 and value = (select max(value)
from january_2017 j
inner join series s on j.series_id = s.series_id
where s.data_type_code = 7)

select i.industry_name 
from january_2017 j 
inner join series s on j.series_id = s.series_id
inner join industry i on i.industry_code = s.industry_code
where s.data_type_code = 7 and value = (select min(value)
from january_2017 j
inner join series s on j.series_id = s.series_id
where s.data_type_code = 7)
-- Out:
-- (2 rows affected)
-- (2 rows affected)
-- Total execution time: 00:00:00.632
-- <table><tr><th>industry_name</th></tr><tr><td>Motor vehicle power train components</td></tr><tr><td>Motor vehicle power train components</td></tr></table>
-- <table><tr><th>industry_name</th></tr><tr><td>Fitness and recreational sports centers</td></tr><tr><td>Fitness and recreational sports centers</td></tr></table>

-- %% [markdown]
-- 7. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2021, which industry was the total weekly payroll for production and nonsupervisory employees the highest? Which industry was the lowest? The industry with highest is Total Private and the lowest is </span> <span style="font-size: 13.3333px; white-space: pre-wrap;">Coin-operated laundries and drycleaners.</span>

-- %%
SELECT j.series_id, avg(j.value) as average_weekely_paY, s.series_title, s.industry_code, s.data_type_code, i.industry_name
from LaborStatisticsDB.dbo.january_2017 as j 
inner join LaborStatisticsDB.dbo.series as s 
on j.series_id = s.series_id
left join LaborStatisticsDB.dbo.industry as i 
on s.industry_code = i.industry_code
where s.data_type_code = 82 and i.industry_name IS NOT NULL
group by j.series_id, j.value, s.series_title, s.industry_code, s.data_type_code, i.industry_name
order by j.value desc;
-- Out:
-- (1032 rows affected)
-- Total execution time: 00:00:01.117
-- <table><tr><th>series_id</th><th>average_weekely_paY</th><th>series_title</th><th>industry_code</th><th>data_type_code</th><th>industry_name</th></tr><tr><td>CES0500000082</td><td>74498171</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>05000000</td><td>82</td><td>Total private</td></tr><tr><td>CEU0500000082</td><td>73474302</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>05000000</td><td>82</td><td>Total private</td></tr><tr><td>CES0800000082</td><td>60914722</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>08000000</td><td>82</td><td>Private service-providing</td></tr><tr><td>CEU0800000082</td><td>60807771</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>08000000</td><td>82</td><td>Private service-providing</td></tr><tr><td>CES6000000082</td><td>15251268</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60000000</td><td>82</td><td>Professional and business services</td></tr><tr><td>CEU6000000082</td><td>15219807</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60000000</td><td>82</td><td>Professional and business services</td></tr><tr><td>CES4000000082</td><td>14850661</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>40000000</td><td>82</td><td>Trade</td></tr><tr><td>CEU6500000082</td><td>14816074</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>65000000</td><td>82</td><td>Education and health services</td></tr><tr><td>CES6500000082</td><td>14765156</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>65000000</td><td>82</td><td>Education and health services</td></tr><tr><td>CEU4000000082</td><td>14732108</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>40000000</td><td>82</td><td>Trade</td></tr><tr><td>CES0600000082</td><td>13426820</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>06000000</td><td>82</td><td>Goods-producing</td></tr><tr><td>CEU6562000082</td><td>12878462</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>65620000</td><td>82</td><td>Health care and social assistance</td></tr><tr><td>CES6562000082</td><td>12762526</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>65620000</td><td>82</td><td>Health care and social assistance</td></tr><tr><td>CEU0600000082</td><td>12711945</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>06000000</td><td>82</td><td>Goods-producing</td></tr><tr><td>CEU6054000082</td><td>8976687</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60540000</td><td>82</td><td>Professional and technical services</td></tr><tr><td>CES6054000082</td><td>8821026</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>60540000</td><td>82</td><td>Professional and technical services</td></tr><tr><td>CES3000000082</td><td>7491723</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>30000000</td><td>82</td><td>Manufacturing</td></tr><tr><td>CEU3000000082</td><td>7411960</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>30000000</td><td>82</td><td>Manufacturing</td></tr><tr><td>CEU5500000082</td><td>6467426</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>55000000</td><td>82</td><td>Financial activities</td></tr><tr><td>CES5500000082</td><td>6328968</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>55000000</td><td>82</td><td>Financial activities</td></tr><tr><td>CES4200000082</td><td>6123554</td><td>Aggregate weekly payrolls of production and nonsupervisory employees</td><td>42000000</td><td>82</td><td>Retail trade</td></tr ...

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Subqueries, Unions, Derived Tables, Oh My!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Write a query that returns the series_id, industry_code, industry_name, and value from the january_2017 table but only if that value is greater than the average value for annual_2016 of data_type_code 82.</span>

-- %%
SELECT j.series_id, s.industry_code, industry_name, j.value
from january_2017 as j 
inner join series as s 
on s.series_id = j.series_id
inner join industry as i 
on s.industry_code = i.industry_code
where data_type_code = 82 and j.value > (select AVG(annual_2016.value)
from annual_2016
where series_id LIKE '%82');
-- Out:
-- (294 rows affected)
-- Total execution time: 00:00:00.263
-- <table><tr><th>series_id</th><th>industry_code</th><th>industry_name</th><th>value</th></tr><tr><td>CES0500000082</td><td>05000000</td><td>Total private</td><td>74498171</td></tr><tr><td>CEU0500000082</td><td>05000000</td><td>Total private</td><td>73474302</td></tr><tr><td>CES0500000082</td><td>05000000</td><td>Total private</td><td>74498171</td></tr><tr><td>CEU0500000082</td><td>05000000</td><td>Total private</td><td>73474302</td></tr><tr><td>CES0600000082</td><td>06000000</td><td>Goods-producing</td><td>13426820</td></tr><tr><td>CEU0600000082</td><td>06000000</td><td>Goods-producing</td><td>12711945</td></tr><tr><td>CES0600000082</td><td>06000000</td><td>Goods-producing</td><td>13426820</td></tr><tr><td>CEU0600000082</td><td>06000000</td><td>Goods-producing</td><td>12711945</td></tr><tr><td>CES0800000082</td><td>08000000</td><td>Private service-providing</td><td>60914722</td></tr><tr><td>CEU0800000082</td><td>08000000</td><td>Private service-providing</td><td>60807771</td></tr><tr><td>CES0800000082</td><td>08000000</td><td>Private service-providing</td><td>60914722</td></tr><tr><td>CEU0800000082</td><td>08000000</td><td>Private service-providing</td><td>60807771</td></tr><tr><td>CES2000000082</td><td>20000000</td><td>Construction</td><td>5335274</td></tr><tr><td>CEU2000000082</td><td>20000000</td><td>Construction</td><td>4724156</td></tr><tr><td>CES2000000082</td><td>20000000</td><td>Construction</td><td>5335274</td></tr><tr><td>CEU2000000082</td><td>20000000</td><td>Construction</td><td>4724156</td></tr><tr><td>CES2023600082</td><td>20236000</td><td>Construction of buildings</td><td>1008035</td></tr><tr><td>CEU2023600082</td><td>20236000</td><td>Construction of buildings</td><td>940800</td></tr><tr><td>CES2023600082</td><td>20236000</td><td>Construction of buildings</td><td>1008035</td></tr><tr><td>CEU2023600082</td><td>20236000</td><td>Construction of buildings</td><td>940800</td></tr><tr><td>CES2023700082</td><td>20237000</td><td>Heavy and civil engineering construction</td><td>908374</td></tr><tr><td>CES2023700082</td><td>20237000</td><td>Heavy and civil engineering construction</td><td>908374</td></tr><tr><td>CES2023800082</td><td>20238000</td><td>Specialty trade contractors</td><td>3421902</td></tr><tr><td>CEU2023800082</td><td>20238000</td><td>Specialty trade contractors</td><td>3062211</td></tr><tr><td>CES2023800082</td><td>20238000</td><td>Specialty trade contractors</td><td>3421902</td></tr><tr><td>CEU2023800082</td><td>20238000</td><td>Specialty trade contractors</td><td>3062211</td></tr><tr><td>CES2023820082</td><td>20238200</td><td>Building equipment contractors</td><td>1696080</td></tr><tr><td>CEU2023820082</td><td>20238200</td><td>Building equipment contractors</td><td>1621266</td></tr><tr><td>CES2023820082</td><td>20238200</td><td>Building equipment contractors</td><td>1696080</td></tr><tr><td>CEU2023820082</td><td>20238200</td><td>Building equipment contractors</td><td>1621266</td></tr><tr><td>CES3000000082</td><td>30000000</td><td>Manufacturing</td><td>7491723</td></tr><tr><td>CEU3000000082</td><td>30000000</td><td>Manufacturing</td><td>7411960</td></tr><tr><td>CES3000000082</td><td>30000000</td><td>Manufacturing</td><td>7491723</td></tr><tr><td>CEU3000000082</td><td>30000000</td><td>Manufacturing</td><td>7411960</td></tr><tr><td>CES3100000082</td><td>31000000</td><td>Durable goods</td><td>4859716</td></tr><tr><td>CEU3100000082</td><td>31000000</td><td>Durable goods</td><td>4808368</td></tr><tr><td>CES3100000082</td><td>31000000</td><td>Durable goods</td><td>4859716</td></tr><tr><td>CEU3100000082</td><td>31000000</td><td>Durable goods</td><td>4808368</td></tr><tr><td>CES3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>871298</td></tr><tr><td>CEU3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>867242</td></tr><tr><td>CES3133200082</td><td>31332000</td><td>Fabricated metal products</td><td>871298</td></tr><tr><td>CEU3133200082</td><td>31332000</td><td>Fabricated metal ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Create a Union table comparing average weekly earnings&nbsp; of production and nonsupervisory employees between annual_16 and january_17 using the data type 30.&nbsp; Round to the nearest penny.&nbsp; You should have a column for the average earnings and a column for the year, and the period.</span>

-- %%
select ROUND(AVG(a.value), 2) as "Avearge earning", MAX(a.year) as "Year", a.period as "Period"
from annual_2016 a 
inner join series s on s.series_id = a.series_id
where s.data_type_code = 30
group by a.year, a.period
UNION
select ROUND(AVG(j.value), 2) as "Avearge earning", MAX(j.year) as "Year", j.period as "Period"
from january_2017 j
inner join series s on s.series_id = j.series_id
where s.data_type_code = 30
group by j.year, j.period
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.162
-- <table><tr><th>Avearge earning</th><th>Year</th><th>Period</th></tr><tr><td>797.2</td><td>2016</td><td>M13</td></tr><tr><td>808.53</td><td>2017</td><td>M01</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size:12pt;font-family:Montserrat, sans-serif;color:rgb(53, 74, 95);background-color:rgb(255, 255, 255);font-weight:700;vertical-align:baseline;white-space:pre-wrap;">Summarize Your Results</span>
--
-- <span style="font-size:10pt;font-family:Arvo, serif;color:rgb(102, 102, 102);background-color:rgb(255, 255, 255);vertical-align:baseline;white-space:pre-wrap;">With what you know now about the </span> <span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:&quot;Times New Roman&quot;;font-size:13.3333px;white-space:pre-wrap;">Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results and working with the</span> <span style="color:rgb(102, 102, 102);white-space:pre-wrap;font-family:&quot;Times New Roman&quot;;font-size:13.3333px;">Labor Statistics Database</span><span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:Arvo, serif;font-size:10pt;white-space:pre-wrap;">, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.</span>
--
-- 1. <span style="background-color:rgb(255, 255, 255);font-size:10pt;white-space:pre-wrap;color:rgb(102, 102, 102);font-family:Arvo, serif;">During which time period did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- In 2017 M01 fared better.

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In which industries did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- Total Private industry fared better.

-- %% [markdown]
-- 3. <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Now that you have explored the datasets, is there any data or information that you wish you had in this analysis?</span>

-- %% [markdown]
-- As per the exploration could see the state with relate which industry will give us the highest wage per state.
